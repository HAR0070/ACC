# %%
from cvxpy import *
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from scipy.signal import cont2discrete , tf2ss
import control as ct
import mplcursors

DEBUG_ = False
import cProfile

# %%
# if ():    
#     # Define the system
# #     A = np.array([[1,0.5,-0.125], [0, 1 , -0.5],[0, 0, 1]])
# #     B = np.array([[-0.0208], [-0.125], [0.5]])
# #     dt = 0.5
# #     A = np.array([[1,0.1,-0.005], [0, 1 , -0.1],[0, 0, 1]])
# #     B = np.array([[-0.0001667], [-0.005], [0.1]])
# #     dt = 0.1
# #     A = np.array([[1,1,-0.5],[0,1,-1],[0,1,1]])
# #     B = np.array([[-0.1667],[-0.5],[1]])
# #     dt = 1
# #     A = np.array([[1,0.05,-0.00125], [0, 1 , -0.05],[0, 0, 1]])
# #     B = np.array([[-0], [-0.00125], [0.05]])
# #     dt = 0.05

# #     T_eng = 0.460
# #     K_eng = 0.732
# #     A_f = -1/T_eng
# #     B_f = -K_eng/T_eng
# #     C = np.eye(3)
# #     T_hw = 1.6
# #     Ts = 0.05
# #     T_total = 10
# #     T = int(T_total/Ts)
# #     v0 = 15           # Initial target velocity
# #     init_dist = 5     # Initial distance between vehicles

# #     # Discretize the system
# #     A = np.array([[0, 1, -T_hw], [0, 0, -1], [0, 0, A_f]])
# #     B = np.array([[0], [0], [B_f]])
# #     sys2   = cont2discrete((A, B, np.eye(3), 0), Ts, method='zoh')
# #     A, B, C, D , dt = sys2

# #     A = np.eye(3) + Ts*A
# #     B = Ts*B
#      C = C_f 
#     # Define the system

# %%
def cvxpy_reverse(A, B, N, Q, R, P, x0, xr, umax=None, umin=None, xmin=None, xmax=None):
    is_sol =  False
    (nx, nu) = B.shape

    # mpc calculation  x0 = distance, x1 = velocity, x2 = accel 
    plt.scatter(xr[0], xr[1], marker='D', color='red', label='reference')
    x = cvxpy.Variable((nx, N + 1))
    u = cvxpy.Variable((nu, N))
    weights = np.ones(5)
    w1 = weights[0]*15
    w2 = weights[1]*2
    w0 = weights[2]*10
    w3 = weights[3]*3
    w4 = weights[4]*100

    costlist = 0.0
    constraints = []

    for t in range(N):
        costlist +=  (w1*((x[1, t]-xr[1])/10) + w2*(x[2, t]-xr[2]) + w0*((x[0, t]-xr[0])/100)) #cvxpy.quad_form(x[:, t]- xr, Q) #
        costlist += w3*u[:, t] #cvxpy.quad_form(u[:, t], R) #

        constraints += [x[:, t + 1] == A * x[:, t] + B * u[:, t]]

        if xmin is not None:
            constraints += [x[0, t] >= xmin[0, 0]]  # state is greater than x min 
            constraints += [x[2, t] >= xmin[1, 0]] # state is greater than x min 
        if xmax is not None:
            constraints += [x[2, t] <= xmax[0]] # state is less than x max 

    # costlist += 0.5 *((x[1, N]-xr[1]) + (x[2, N]-xr[2]) + (x[0, N]-xr[0])) # terminal cost #0.5 *((x[1, N]-xr[1])**2 + (x[2, N]-xr[2])**2 + (x[0, N]-xr[0])**2)  # terminal cost
    costlist += w4*((x[1, N]-xr[1]) + (x[2, N]-xr[2]) + (x[0, N]-xr[0]))
    if xmin is not None:
        constraints += [x[0, t] >= xmin[0, 0]]  # state is greater than x min 
        constraints += [x[2, t] >= xmin[1, 0]]
    if xmax is not None:
        constraints += [x[2, t] <= xmax[0]]

    if umax is not None:
        constraints += [u <= umax]  # input constraints
    if umin is not None:
        constraints += [u >= umin]  # input constraints

    # print("this is inside functio",x0)
    constraints += [x[:, 0] == x0]  # inital state constraints

    prob = cvxpy.Problem(cvxpy.Minimize(costlist), constraints)

    prob.solve(solver=ECOS , warm_start=True) #solver= OSQP,
    if prob.status == 'optimal':
        is_sol = True
    
    return is_sol , x.value, u.value, costlist.value

# %%
def cvxpy_reverse1(A, B, N, Q, R, P, x0, xr, umax=None, umin=None, xmin=None, xmax=None):  
    is_sol =  False
    (nx, nu) = B.shape

    # mpc calculation  x0 = distance, x1 = velocity, x2 = accel 
    x = cvxpy.Variable((nx, N + 1))
    u = cvxpy.Variable((nu, N))
    weights = np.ones(5)
    w0 = weights[0]*20
    w1 = weights[1]*5
    w2 = weights[2]*3
    w3 = weights[3]*2
    w4 = weights[4]*0.5
    R = np.eye(nu)

    costlist = 0.0
    constraints = []

    for t in range(N):
        # costlist +=  cvxpy.quad_form(x[:, t] - xr[1], Q)
        # derr = min((x[0, t]-xr[0]), 30)
        # verr = min((x[1, t]-xr[1]), 5)
        # aerr = min( (x[2, t]-xr[2]) , 1.5)
        costlist +=  (w1*((x[1, t]-xr[1])) + w2*(x[2, t]-xr[2]) + w0*((x[0, t]-xr[0]))) #cvxpy.quad_form(x[:, t]- xr, Q) #
        # costlist += cvxpy.quad_form(u[:, t], R)
        costlist += w3*u[:, t]

        constraints += [x[:, t + 1] == A * x[:, t] + B * u[:, t]]

        if xmin is not None:
            constraints += [x[0, t] >= xmin[0, 0]]  # state is greater than x min
             
            # constraints += [xr[1] - x[1,t]  >= xmin[1, 0]]
            constraints += [x[2, t] >= xmin[1, 0]]
        if xmax is not None:
            constraints += [x[2, t] <= xmax[0]] # state is less than x max 

    # costlist += 0.5 *((x[1, N]-xr[1]) + (x[2, N]-xr[2]) + (x[0, N]-xr[0])) # terminal cost #0.5 *((x[1, N]-xr[1])**2 + (x[2, N]-xr[2])**2 + (x[0, N]-xr[0])**2)  # terminal cost
    costlist += w4 *((x[1, N]-xr[1]) + (x[2, N]-xr[2])**2 + (x[0, N]-xr[0]))
    # costlist +=  cvxpy.quad_form(x[:, N] - xr[1], P)
    if xmin is not None:
        constraints += [x[0, N] >= xmin[0, 0]]  # state is greater than x min 
        constraints += [x[2, N] >= xmin[1, 0]]
    if xmax is not None:
        constraints += [x[2, N] <= xmax[0]] # state is less than x max 

    if umax is not None:
        constraints += [u <= umax]  # input constraints
    if umin is not None:
        constraints += [u >= umin]  # input constraints

    ur1_max = 2
    ur1_min = -2
    # add input rate constraints
    # rate of change of u1 constraint
    for i in range(N-1):
        constraints += [ (u[0,i+1] - u[0,i]) <= ur1_max]
        constraints += [ (u[0,i+1] - u[0,i]) >= ur1_min]

    # print("this is inside functio",x0)
    constraints += [x[:, 0] == x0]  # inital state constraints

    prob = cvxpy.Problem(cvxpy.Minimize(costlist), constraints)

    prob.solve(solver=ECOS , warm_start=True) #solver= OSQP,
        
    if prob.status == 'optimal':
    # Problem was solved successfully
        is_sol = True
        print("Optimal solution found!")
    elif prob.status == 'infeasible':
        # Problem is infeasible (no feasible solution exists)
        print("Problem is infeasible.")
    elif prob.status == 'unbounded':
        # Problem is unbounded (no finite optimal solution exists)
        print("Problem is unbounded.")
    else:
        # Solver failed or terminated prematurely
        print("Solver failed or terminated prematurely. Status:", prob.status)
    
    return is_sol , x.value, u.value[:,0], costlist.value

# %%
def cvxpy_reverse2(A, B, N, Q, R, P, x0, xr, umax=None, umin=None, xmin=None, xmax=None):  
    is_sol =  False
    (nx, nu) = B.shape

    # mpc calculation  x0 = distance, x1 = velocity, x2 = accel 
    x = cvxpy.Variable((nx, N + 1))
    u = cvxpy.Variable((nu, N))
    weights = np.ones(8)
    w0 = weights[0]*0.1
    w1 = weights[1]*0.5
    w2 = weights[2]*0.15
    w3 = weights[3]*0.5
    w4 = weights[4]*0.05
    k1 = weights[5]*0.05
    k2 = weights[6]*0.2
    k3 = weights[7]*0.05
    # R = np.eye(nu)

    costlist = 0.0
    constraints = []

    for t in range(N):
        
        costlist +=  cvxpy.quad_form(x[:, t], Q) 
        # + k1*((x[0, t]-xr[0])*(x[1, t]-xr[1])) + k3*((x[2, t]-xr[2])*(x[0, t]-xr[0]))  + k2*((x[1, t]-xr[1])*(x[2, t]-xr[2]))
        # costlist += (w1*((x[1, t]-xr[1])) + w2*(x[2, t]-xr[2]) + w0*((x[0, t]-xr[0])))
        costlist += cvxpy.quad_form(u[:, t], R)
        # costlist += w3*(u[:, t] *u[:, t])

        constraints += [x[:, t + 1] == A * x[:, t] + B * u[:, t]]

        if xmin is not None:
            constraints += [x[0, t] >= xmin[0, 0]]  # state is greater than x min
             
            # constraints += [xr[1] - x[1,t]  >= xmin[1, 0]]
            constraints += [x[2, t] >= xmin[1, 0]]
        if xmax is not None:
            constraints += [x[2, t] <= xmax[0]] # state is less than x max 
        if umax is not None:
            constraints += [u[:, t] <= umax]  # input constraints
        if umin is not None:
            constraints += [u[:, t] >= umin]  # input constraints

    # costlist += 0.5 *((x[1, N]-xr[1]) + (x[2, N]-xr[2]) + (x[0, N]-xr[0])) # terminal cost #0.5 *((x[1, N]-xr[1])**2 + (x[2, N]-xr[2])**2 + (x[0, N]-xr[0])**2)  # terminal cost
    # costlist += w4 *((x[1, N]) + (x[2, N])**2 + (x[0, N]))
    costlist +=  cvxpy.quad_form(x[:, N], P)

    constraints += [x[:, 0] == x0]  # inital state constraints
    
    ur1_max = 2
    ur1_min = -2
    # add input rate constraints
    # rate of change of u1 constraint
    # for i in range(N-1):
    #     constraints += [ (u[0,i+1] - u[0,i]) <= ur1_max]
    #     constraints += [ (u[0,i+1] - u[0,i]) >= ur1_min]

    # print("this is inside functio",x0)
    
    prob = cvxpy.Problem(cvxpy.Minimize(costlist), constraints)

    prob.solve(solver=ECOS ) #solver= OSQP, ECOS, , warm_start=True
        
    if prob.status == 'optimal':
    # Problem was solved successfully
        is_sol = True
        print("Optimal solution found!")
    elif prob.status == 'infeasible':
        # Problem is infeasible (no feasible solution exists)
        print("Problem is infeasible.")
    elif prob.status == 'unbounded':
        # Problem is unbounded (no finite optimal solution exists)
        print("Problem is unbounded.")
    else:
        # Solver failed or terminated prematurely
        print("Solver failed or terminated prematurely. Status:", prob.status)
    
    return is_sol , x.value, u.value[:,0], costlist.value

# %%
def plotting(x_hist,u_hist,cost_hist,Xh,Xr,host_d, DEBUG_=True):
    
    if DEBUG_:
        u_hist = np.array(u_hist).squeeze()
        cost_hist = np.array(cost_hist)

        # Plot the responses and cost
        plt.figure(figsize=(16, 16))    
        plt.subplot(3, 1, 1)
        plt.plot(x_hist[:, 0], label='Dist', linewidth=2.5)
        plt.plot(-x_hist[:, 1], label='Velocity', linewidth=2.5)

        plt.legend()
        plt.title('MPC Response', fontsize=20)
        plt.ylabel('Distance and velocity', fontsize=16)
        plt.xlabel('Time', fontsize=16)
        plt.grid()

        plt.subplot(3, 1, 2)
        plt.plot(u_hist, label='u')
        plt.legend()
        plt.ylabel('Input')
        plt.grid()

        plt.subplot(3, 1, 3)
        plt.plot(cost_hist, label=' Cost')
        plt.legend()
        plt.xlabel('Time')
        plt.ylabel('Cost')
        plt.grid()
        
        # plt.subplot(4, 1, 4)
        # plt.plot(x_hist[:,2], label='Host accel')
        # # plt.plot(Xr, label='refernce distance')
        # plt.legend()
        # plt.ylabel('distance')
        # plt.grid()

        plt.figure(figsize=(8, 8))
        plt.subplot(3, 1, 1)
        plt.plot(host_d, label='difference in distance')
        plt.legend()
        plt.ylabel('meters')
        plt.grid()

        plt.subplot(3, 1, 2)
        plt.plot(x_hist[:, 2], label='accel')
        plt.legend()
        plt.ylabel('accel')
        plt.grid()
        plt.show()

# %%
def reference1(T_total, Ts, init_dist, v0):  # Generate accel constant decel reference trajectory
# if __name__ == "__main__":
#     
#    T_total = 30
#     Ts = 0.1
#     init_dist = 6
#     v0 = 0
    a = 1; # acceleration
    b = -1; # deceleration
    T1 = int(2/Ts)
    T2 = int(12/Ts)
    T3 = int(17/Ts)
    T4 = int(25/Ts)
    T =  int(T_total/Ts)

    x_current = np.zeros((T, 3)) # distance and velocity refernce is given 
    
    x_current[0, 0] = init_dist; 
    x_current[0, 1] = v0; 
    x_current[:, 2] = 0; 

    for k in range(1,T1 ):
        x_current[k, 0] = x_current[k-1, 0] + x_current[k-1, 1]*Ts; 
        x_current[k, 1] = 0; 
        x_current[k, 2] = 0
    
    for k in range(T1 ,T2 ):
        x_current[k, 0] = x_current[k-1, 0] + x_current[k-1, 1]*Ts + (0.5*a)*Ts**2; 
        x_current[k, 1] = x_current[k-1, 1] + a*Ts; 
        x_current[k, 2] = a

    for k in range(T2 ,T3 ):
        x_current[k, 0] = x_current[k-1, 0] + x_current[k-1,1]*Ts; 
        x_current[k, 1] = x_current[k-1, 1]; 
        x_current[k, 2] = 0

    for k in range(T3 ,T4 ):
        x_current[k, 0] = x_current[k-1, 0] + x_current[k-1, 1]*Ts + (0.5*b)*Ts**2; 
        x_current[k, 1] = x_current[k-1, 1] + b*Ts; 
        x_current[k, 2] = b

    for k in range(T4 ,T ):
        x_current[k, 0] = x_current[k-1, 0] + x_current[k-1,1]*Ts; 
        x_current[k, 1] = x_current[k-1, 1]; 
        x_current[k, 2] = 0
    
    
    y = np.arange(0, T_total, Ts)
    plt.plot(y , x_current[:,0], label='reference distance', linewidth=2.5)
    plt.plot(y , x_current[:,1], label='reference velocity', linewidth=2.5)
    plt.xlabel('time')
    plt.legend()
    plt.ylabel('distance')
    plt.grid()
    plt.show()
    
    return x_current

def reference2(T_total, Ts, init_dist, v0):  # Generate stop accel constant trajectory
# if __name__ == "__main__":    
    T_total = 30
#     Ts = 0.1
#     init_dist = 6
#     v0 = 0
    a = 0.2; # acceleration
    b = -2; # deceleration
    T1 = int(8/Ts)
    T2 = int(15/Ts)
    T =  int(T_total/Ts)

    x_current = np.zeros((T, 3)) # distance and velocity refernce is given 
    
    x_current[0, 0] = init_dist; 
    x_current[0, 1] = v0; 
    x_current[:, 2] = 0; 

    for k in range(1,T1 ):
        x_current[k, 0] = x_current[k-1, 0] + x_current[k-1, 1]*Ts; 
        x_current[k, 1] = x_current[k-1, 1] 
        x_current[k, 2] = 0
    
    for k in range(T1 ,T2 ):
        x_current[k, 0] = x_current[k-1, 0] + x_current[k-1, 1]*Ts + (0.5*a)*Ts**2; 
        x_current[k, 1] = x_current[k-1, 1] + a*Ts; 
        x_current[k, 2] = a

    for k in range(T2 ,T ):
        x_current[k, 0] = x_current[k-1, 0] + x_current[k-1,1]*Ts; 
        x_current[k, 1] = x_current[k-1, 1]; 
        x_current[k, 2] = 0

    y = np.arange(0, T_total, Ts)
    plt.plot(y , x_current[:,0], label='reference distance', linewidth=2.5)
    plt.plot(y , x_current[:,1], label='reference velocity', linewidth=2.5)
    plt.xlabel('time')
    plt.legend()
    plt.ylabel('distance')
    plt.grid()
    plt.show()
    
    return x_current

def reference3(T_total, Ts, init_dist, v0):  # long pause quick accelerate and constant trajectory
# if __name__ == "__main__":    
#    T_total = 30
#     Ts = 0.1
#     init_dist = 6
#     v0 = 0
    a = 1.5; # acceleration
    b = -2; # deceleration
    T1 = int(15/Ts)
    T2 = int(18/Ts)
    T =  int(T_total/Ts)

    x_current = np.zeros((T, 3)) # distance and velocity refernce is given 
    
    x_current[0, 0] = init_dist 
    x_current[0, 1] = v0
    x_current[:, 2] = 0

    for k in range(1,T1 ):
        x_current[k, 0] = x_current[k-1, 0] + x_current[k-1,1]*Ts 
        x_current[k, 1] = x_current[k-1, 1]
        x_current[k, 2] = 0
    
    for k in range(T1 ,T2 ):
        x_current[k, 0] = x_current[k-1, 0] + x_current[k-1, 1]*Ts + (0.5*a)*Ts**2
        x_current[k, 1] = x_current[k-1, 1] + a*Ts
        x_current[k, 2] = a

    for k in range(T2 ,T ):
        x_current[k, 0] = x_current[k-1, 0] + x_current[k-1,1]*Ts 
        x_current[k, 1] = x_current[k-1, 1] 
        x_current[k, 2] = 0

    y = np.arange(0, T_total, Ts)
    plt.plot(y , x_current[:,0], label='reference distance', linewidth=2.5)
    plt.plot(y , x_current[:,1], label='reference velocity', linewidth=2.5)
    plt.xlabel('time')
    plt.legend()
    plt.ylabel('distance')
    plt.grid()
    plt.show()
    
    return x_current

# %%
def reverse():
    print("start!! reverse ")
    T_eng =  0.460 #0.26  #
    K_eng = 0.732
    A_f = -1/T_eng
    B_f = K_eng/T_eng
    C = np.eye(3)
    T_hw = 3
    Ts = 0.05
    T_total = 30
    T = int(T_total/Ts)


    # Discretize the system
    A = np.array([[0, 1, -T_hw], [0, 0, -1], [0, 0, A_f]])
    B = np.array([[0], [0], [B_f]])
    sys2 = cont2discrete((A,B, C, 0), Ts, method='zoh')
    A, B, C, D , dt = sys2
    
    (nx, nu) = B.shape

    Q = np.array([[1, 0, 0],[0,0.8,0],[0,0,0.5]])
    R = np.eye(nu)*0.7
    P = np.eye(nx)*0.1

    ## x represents states 

    umax = 4
    umin = -4 

    xmin = np.array([[0] ,[-3.5]])  # state constraints
    xmax = np.array([2.5])  # state constraints

    x0 = np.array([40, 2.0, 0])  # initial state

    init_dist = x0[0] # initial distance between vehicles
    v0 = 5 # initial velocity of the reference vehicle
    
    x_current = reference2(T_total, Ts,init_dist , v0) # reference trajectory
    
    N = 20  # horizon
    iter = T #T # number of iteration
    x_hist = [x0]
    u_hist = [0]
    cost_hist = []
    xh = x_current[0,0] - x0[0]  # initial position of the host
    vh = x_current[0,1] - x0[1]  # initial velocity of the host
    d0 = 2 # tailgating distance between vehicles
    host_d = np.zeros((iter, 1))
    host_v = np.zeros((iter, 1))
    b = 0

    for i in range(iter):  #iter
        x_r = x_current[i, :] # is reference vehicle parameters
        d_ref = x_r[0] - (xh + T_hw*vh + d0)
        v_ref = x_r[1] - vh   # current values  

        x0 = np.array([d_ref, v_ref, x0[2]]) # referance state
        xr = np.array([0, 0 , 0]) # referance state
        try:
            notfail, x, u, c = cvxpy_reverse2(A, B, N, Q, R, P, x0, xr, umax = umax, umin = umin, xmin = xmin, xmax = xmax)
        except:
            u =  u_hist[-1] #np.array([-2.5])
            c = -1 
            b += 1
            print('No solution',b)
        
        x0 = A.dot(x0) + B.dot(u) #+ np.ranfdom.multivariate_normal(np.zeros(3), W)
        try:
            if len(x0[0]) >1:
                x0 = x0[0]
        except:
            pass
        
        print("this is car's states",x0,u)
        u_hist.append(u)
        print('Iteration:', i, 'Cost:', c, 'Input:', u)
        x_hist.append(x0)
        vh = vh + x0[2]*Ts
        xh = xh + vh*Ts + 0.5*x0[2]*Ts**2 
          
        host_d[i] = xh
        host_v[i] =  vh
        cost_hist.append(c)

    
    #################
    ##Plotings only
    ##below 
    #################
   
    x_hist = np.array(x_hist)
    u_hist = np.array(u_hist)
    cost_hist = np.array(cost_hist)
    u_limit = np.ones((iter, 2))
    u_limit[:,0] = umax
    u_limit[:,1] = umin

    acceleration  = np.diff(host_v[1:-1], axis=0)/Ts
    velocity = np.diff(host_d[1:-1], axis=0)/Ts
    
    # diff = x_current[0:iter+1,0] - x_hist[0:iter+1,0] 

    print("aa")
    plt.figure(figsize=(16, 32))    
    plt.subplot(5, 1, 1)
    plt.plot(host_d, label='host position', linewidth=2.5)
    plt.plot(x_current[0:iter,0], label='reference position', linewidth=2.5)
    plt.xlabel('Time/0.05' , fontsize=16)
    plt.xticks(fontsize=12)
    plt.legend()
    plt.grid(True)

    plt.subplot(5, 1, 2)
    plt.plot(host_v, label='host velocity', linewidth=2.5)
    plt.plot(x_current[0:iter,1], label='reference velocity', linewidth=2.5)
    # plt.plot(velocity, label='velocity', linewidth=2.5, linestyle = '-.')
    plt.xlabel('Time/0.05' , fontsize=16)
    plt.xticks(fontsize=12)
    plt.legend()
    plt.grid(True)

    plt.subplot(5, 1, 3)
    plt.plot(x_hist[0:iter,2], label='host accel', linewidth=2.5)
    plt.plot(x_current[0:iter,2], label='reference accel', linewidth=2.5)
    plt.plot(u_hist, label='input', linewidth=2.5)
    
    plt.xlabel('Time/0.05' , fontsize=16)
    plt.xticks(fontsize=12)
    plt.grid(True)
    plt.legend()

    plt.subplot(5, 1, 4)
    plt.plot(x_hist[:,0], label='state del d', linewidth=2.5)
    plt.xlabel('Time/0.05' , fontsize=12)
    plt.grid(True)
    plt.legend()

    plt.subplot(5, 1, 5)
    plt.plot(x_hist[:,1], label='state del v', linewidth=2.5)
    plt.xlabel('Time/0.05' , fontsize=12)
    plt.grid(True)
    plt.legend()


    plt.show()
    
    plt.plot(acceleration, label='acceleration', linewidth=2.5)
    plt.show()
    
    plotting(x_hist,u_hist,cost_hist,host_d,x_current[:,0], host_d,True)
    
    return x_hist #cost_hist

# %%
if __name__ == '__main__':
    DEBUG_ = False
    Ts = 0.05
    #x_rev = cProfile.run('reverse()')
    x_rev = reverse()
    # print(x_rev)
# Out:
# start!! reverse
# Optimal solution found!
# this is car's states [29.07684319  1.99232409  0.30157411] [3.99999995]
# Iteration: 0 Cost: 15933.204227574679 Input: [3.99999995]
# Optimal solution found!
# this is car's states [29.08649423  1.96295727  0.57208711] [3.99999999]
# Iteration: 1 Cost: 15691.762634218714 Input: [3.99999999]
# Optimal solution found!
# this is car's states [29.05757601  1.92153643  0.81473817] [3.99999995]
# Iteration: 2 Cost: 15429.184475106531 Input: [3.99999995]
# Optimal solution found!
# this is car's states [28.99330711  1.86930309  1.032397  ] [3.99999999]
# Iteration: 3 Cost: 15147.643646338654 Input: [3.99999999]
# Optimal solution found!
# this is car's states [28.89657459  1.80737091  1.22763771] [3.99999993]
# Iteration: 4 Cost: 14849.733850789095 Input: [3.99999993]
# Optimal solution found!
# this is car's states [28.76996816  1.73673882  1.40276928] [3.99999999]
# Iteration: 5 Cost: 14537.895085143624 Input: [3.99999999]
# Optimal solution found!
# this is car's states [28.61581079  1.65830289  1.55986289] [4.]
# Iteration: 6 Cost: 14213.962312141417 Input: [4.]
# Optimal solution found!
# this is car's states [28.43618621  1.5728669   1.70077639] [3.99999995]
# Iteration: 7 Cost: 13879.630102213692 Input: [3.99999995]
# Optimal solution found!
# this is car's states [28.23296352  1.48115182  1.82717628] [3.99999996]
# Iteration: 8 Cost: 13536.462371525718 Input: [3.99999996]
# Optimal solution found!
# this is car's states [28.0078193   1.38380437  1.9405574 ] [3.99999994]
# Iteration: 9 Cost: 13185.902209631271 Input: [3.99999994]
# Optimal solution found!
# this is car's states [27.76225747  1.28140468  2.04226065] [3.99999997]
# Iteration: 10 Cost: 12829.28116926476 Input: [3.99999997]
# Optimal solution found!
# this is car's states [27.49762703  1.17447311  2.1334888 ] [3.99999982]
# Iteration: 11 Cost: 12467.828662386795 Input: [3.99999982]
# Optimal solution found!
# this is car's states [27.21513805  1.06347642  2.21532077] [3.99999998]
# Iteration: 12 Cost: 12102.680088896475 Input: [3.99999998]
# Optimal solution found!
# this is car's states [26.91587597  0.94883331  2.28872432] [3.99999993]
# Iteration: 13 Cost: 11734.886085895314 Input: [3.99999993]
# Optimal solution found!
# this is car's states [26.60081443  0.83091935  2.35456755] [3.99999999]
# Iteration: 14 Cost: 11365.412848154716 Input: [3.99999999]
# Optimal solution found!
# this is car's states [26.27082677  0.71007142  2.41362915] [3.9999999]
# Iteration: 15 Cost: 10995.15756961879 Input: [3.9999999]
# Optimal solution found!
# this is car's states [25.9266964   0.58659171  2.46660761] [3.99999998]
# Iteration: 16 Cost: 10624.958207804906 Input: [3.99999998]
# Optimal solution found!
# this is car's states [25.570211    0.46111093  2.49999999] [3.81259027]
# Iteration: 17 Cost: 10255.595156304691 Input: [3.81259027]
# Optimal solution found!
# this is car's states [25.20636405  0.33529124  2.49999998] [3.4153004]
# Iteration: 18 Cost: 9889.903418342341 Input: [3.4153004]
# Optimal solution found!
# this is car's states [24.83875362  0.21029124  2.49999997] [3.41530039]
# Iteration: 19 Cost: 9530.58310403886 Input: [3.41530039]
# Optimal solution found!
# this is car's states [24.46489318  0.08529125  2.49999998] [3.41530069]
# Iteration: 20 Cost: 9173.652135121125 Input: [3.41530069]
# Optimal solution found!
# this is car's states [24.08478275 -0.03970875  2.49999997] [3.41530043]
# Iteration: 21 Cost: 8819.432002055197 Input: [3.41530043]
# Optimal solution found!
# this is car's states [23.69842231 -0.16470875  2.49999999] [3.41530068]
# Iteration: 22 Cost: 8468.248509887168 Input: [3.41530068]
# Optimal solution found!
# this is car's states [23.30581188 -0.28970875  2.49999997] [3.41530032]
# Iteration: 23 Cost: 8120.432593530776 Input: [3.41530032]
# Optimal solution found!
# this is car's states [22.90695145 -0.41470875  2.49999998] [3.41530056]
# Iteration: 24 Cost: 7776.319453079522 Input: [3.41530056]
# Optimal solution found!
# this is car's states [22.50184101 -0.53970875  2.49999999] [3.41530066]
# Iteration: 25 Cost: 7436.2421673994295 Input: [3.41530066]
# Optimal solution found!
# this is car's states [22.09048057 -0.66470875  2.49999999] [3.41530059]
# Iteration: 26 Cost: 7100.526243279687 Input: [3.41530059]
# Optimal solution found!
# this is car's states [21.67287014 -0.78970875  2.49999999] [3.4153005]
# Iteration: 27 Cost: 6769.519235550299 Input: [3.4153005]
# Optimal solution found!
# this is car's states [21.2490097  -0.91470875  2.49999998] [3.41530047]
# Iteration: 28 Cost: 6443.574397007659 Input: [3.41530047]
# Optimal solution found!
# this is car's states [20.81889927 -1.03970875  2.49999999] [3.41530056]
# Iteration: 29 Cost: 6123.049680697049 Input: [3.41530056]
# Optimal solution found!
# this is car's states [20.38253883 -1.16470875  2.49999999] [3.41530062]
# Iteration: 30 Cost: 5808.307728610663 Input: [3.41530062]
# Optimal solution found!
# this is car's states [19.9399284  -1.28970875  2.49999999] [3.41530044]
# Iteration: 31 Cost: 5499.715784037241 Input: [3.41530044]
# Optimal solution found!
# this is car's states [19.49106796 -1.41470875  2.49999999] [3.41530062]
# Iteration: 32 Cost: 5197.615933847015 Input: [3.41530062]
# Optimal solution found!
# this is car's states [19.03595752 -1.53970874  2.5       ] [3.41530057]
# Iteration: 33 Cost: 4902.361237907745 Input: [3.41530057]
# Optimal solution found!
# this is car's states [18.57459709 -1.66470874  2.49999999] [3.41530049]
# Iteration: 34 Cost: 4614.331381919799 Input: [3.41530049]
# Optimal solution found!
# this is car's states [18.10698665 -1.78970874  2.49999999] [3.41530057]
# Iteration: 35 Cost: 4333.91070877362 Input: [3.41530057]
# Optimal solution found!
# this is car's states [17.63312621 -1.91470874  2.5       ] [3.41530056]
# Iteration: 36 Cost: 4061.4683988172305 Input: [3.41530056]
# Optimal solution found!
# this is car's states [17.15301578 -2.03970874  2.49999999] [3.41530051]
# Iteration: 37 Cost: 3797.3336443894073 Input: [3.41530051]
# Optimal solution found!
# this is car's states [16.66665534 -2.16470874  2.5       ] [3.41530057]
# Iteration: 38 Cost: 3541.897420310869 Input: [3.41530057]
# Optimal solution found!
# this is car's states [16.17404491 -2.28970874  2.5       ] [3.41530053]
# Iteration: 39 Cost: 3295.5428425862046 Input: [3.41530053]
# Optimal solution found!
# this is car's states [15.67518447 -2.41470874  2.5       ] [3.41530056]
# Iteration: 40 Cost: 3058.573089253222 Input: [3.41530056]
# Optimal solution found!
# this is car's states [15.17007403 -2.53970874  2.5       ] [3.41530055]
# Iteration: 41 Cost: 2831.3769673388815 Input: [3.41530055]
# Optimal solution found!
# this is car's states [14.65871359 -2.66470874  2.5       ] [3.41530054]
# Iteration: 42 Cost: 2614.254923827982 Input: [3.41530054]
# Optimal solution found!
# this is car's states [14.14110316 -2.78970874  2.5       ] [3.41530052]
# Iteration: 43 Cost: 2407.535444409612 Input: [3.41530052]
# Optimal solution found!
# this is car's states [13.61724272 -2.91470874  2.5       ] [3.41530057]
# Iteration: 44 Cost: 2211.4757940572845 Input: [3.41530057]
# Optimal solution found!
# this is car's states [13.08713228 -3.03970874  2.5       ] [3.41530053]
# Iteration: 45 Cost: 2026.3532233567316 Input: [3.41530053]
# Optimal solution found!
# this is car's states [12.55077185 -3.16470874  2.49999999] [3.4153005]
# Iteration: 46 Cost: 1852.3371264335112 Input: [3.4153005]
# Optimal solution found!
# this is car's states [12.00816141 -3.28970874  2.5       ] [3.41530056]
# Iteration: 47 Cost: 1689.5714321297405 Input: [3.41530056]
# Optimal solution found!
# this is car's states [11.45930098 -3.41470874  2.5       ] [3.41530057]
# Iteration: 48 Cost: 1538.141522662836 Input: [3.41530057]
# Optimal solution found!
# this is car's states [10.90419054 -3.53970874  2.49999999] [3.41530039]
# Iteration: 49 Cost: 1398.0301894946074 Input: [3.41530039]
# Optimal solution found!
# this is car's states [10.3428301  -3.66470874  2.49999999] [3.41530062]
# Iteration: 50 Cost: 1269.136218004929 Input: [3.41530062]
# Optimal solution found!
# this is car's states [ 9.77521967 -3.78970874  2.49999998] [3.41530033]
# Iteration: 51 Cost: 1151.267603310007 Input: [3.41530033]
# Optimal solution found!
# this is car's states [ 9.20135924 -3.91470874  2.49999999] [3.41530063]
# Iteration: 52 Cost: 1044.1404815443173 Input: [3.41530063]
# Optimal solution found!
# this is car's states [ 8.62364533 -4.03891435  2.46878969] [3.00133534]
# Iteration: 53 Cost: 947.3837974980615 Input: [3.00133534]
# Optimal solution found!
# this is car's states [ 8.05040492 -4.15962558  2.39170072] [2.35017559]
# Iteration: 54 Cost: 862.720118109164 Input: [2.35017559]
# Optimal solution found!
# this is car's states [ 7.48922469 -4.27443774  2.27852849] [1.76626394]
# Iteration: 55 Cost: 790.2705411415668 Input: [1.76626394]
# Optimal solution found!
# this is car's states [ 6.94456016 -4.3820012   2.1376832 ] [1.24460877]
# Iteration: 56 Cost: 728.4894077803162 Input: [1.24460877]
# Optimal solution found!
# this is car's states [ 6.42053757 -4.48109047  1.96726837] [0.65999464]
# Iteration: 57 Cost: 676.2088222972249 Input: [0.65999464]
# Optimal solution found!
# this is car's states [ 5.92163249 -4.57039199  1.77559264] [0.14518849]
# Iteration: 58 Cost: 632.5130279650706 Input: [0.14518849]
# Optimal solution found!
# this is car's states [ 5.45033444 -4.64925878  1.57098869] [-0.28814016]
# Iteration: 59 Cost: 595.7728955991272 Input: [-0.28814016]
# Optimal solution found!
# this is car's states [ 5.00801077 -4.71741847  1.36011648] [-0.65079433]
# Iteration: 60 Cost: 564.6198672261589 Input: [-0.65079433]
# Optimal solution found!
# this is car's states [ 4.59525112 -4.77485552  1.14825532] [-0.95198828]
# Iteration: 61 Cost: 537.9420679414715 Input: [-0.95198828]
# Optimal solution found!
# this is car's states [ 4.21202887 -4.82175453  0.93950992] [-1.20008955]
# Iteration: 62 Cost: 514.837379259528 Input: [-1.20008955]
# Optimal solution found!
# this is car's states [ 3.85784092 -4.8584517   0.7370094 ] [-1.40243032]
# Iteration: 63 Cost: 494.57580625601287 Input: [-1.40243032]
# Optimal solution found!
# this is car's states [ 3.53182217 -4.88539516  0.54307435] [-1.56546029]
# Iteration: 64 Cost: 476.5690296537995 Input: [-1.56546029]
# Optimal solution found!
# this is car's states [ 3.23284074 -4.90311224  0.35935854] [-1.69485342]
# Iteration: 65 Cost: 460.3453875494625 Input: [-1.69485342]
# Optimal solution found!
# this is car's states [ 2.95957632 -4.91218273  0.18697193] [-1.79556391]
# Iteration: 66 Cost: 445.52910399450593 Input: [-1.79556391]
# Optimal solution found!
# this is car's states [ 2.71058396 -4.9132174   0.0265841 ] [-1.87191599]
# Iteration: 67 Cost: 431.8230322274731 Input: [-1.87191599]
# Optimal solution found!
# this is car's states [ 2.48434565 -4.90684067 -0.12148844] [-1.92767827]
# Iteration: 68 Cost: 418.99420869992076 Input: [-1.92767827]
# Optimal solution found!
# this is car's states [ 2.27931158 -4.89367706 -0.25720734] [-1.96610782]
# Iteration: 69 Cost: 406.86175733809034 Input: [-1.96610782]
# Optimal solution found!
# this is car's states [ 2.09393267 -4.87434059 -0.38075287] [-1.99005158]
# Iteration: 70 Cost: 395.2868425627711 Input: [-1.99005158]
# Optimal solution found!
# this is car's states [ 1.92668601 -4.84942675 -0.49246974] [-2.0019376]
# Iteration: 71 Cost: 384.16418798517293 Input: [-2.0019376]
# Optimal solution found!
# this is car's states [ 1.77609382 -4.81950658 -0.59282565] [-2.00386724]
# Iteration: 72 Cost: 373.41521211325187 Input: [-2.00386724]
# Optimal solution found!
# this is car's states [ 1.64073769 -4.78512255 -0.68237573] [-1.99763995]
# Iteration: 73 Cost: 362.98225621317965 Input: [-1.99763995]
# Optimal solution found!
# this is car's states [ 1.5192686  -4.74678566 -0.76173404] [-1.98479519]
# Iteration: 74 Cost: 352.82390358882765 Input: [-1.98479519]
# Optimal solution found!
# this is car's states [ 1.41041355 -4.70497393 -0.83154994] [-1.96664006]
# Iteration: 75 Cost: 342.9111668508702 Input: [-1.96664006]
# Optimal solution found!
# this is car's states [ 1.31297941 -4.66013157 -0.89248939] [-1.94428204]
# Iteration: 76 Cost: 333.2244314288482 Input: [-1.94428204]
# Optimal solution found!
# this is car's states [ 1.22585466 -4.61266905 -0.94522036] [-1.91865758]
# Iteration: 77 Cost: 323.7510117842179 Input: [-1.91865758]
# Optimal solution found!
# this is car's states [ 1.14800937 -4.56296366 -0.99040123] [-1.89055191]
# Iteration: 78 Cost: 314.48321273390394 Input: [-1.89055191]
# Optimal solution found!
# this is car's states [ 1.07849384 -4.51136043 -1.02867208] [-1.86062163]
# Iteration: 79 Cost: 305.4168268459438 Input: [-1.86062163]
# Optimal solution found!
# this is car's states [ 1.01643624 -4.45817351 -1.06064814] [-1.82941186]
# Iteration: 80 Cost: 296.54997102541455 Input: [-1.82941186]
# Optimal solution found!
# this is car's states [ 0.96103947 -4.40368761 -1.08691521] [-1.79737234]
# Iteration: 81 Cost: 287.882206871993 Input: [-1.79737234]
# Optimal solution found!
# this is car's states [ 0.91157754 -4.34815972 -1.10802648] [-1.76487118]
# Iteration: 82 Cost: 279.4138855935737 Input: [-1.76487118]
# Optimal solution found!
# this is car's states [ 0.86739155 -4.29182086 -1.1245007 ] [-1.73220707]
# Iteration: 83 Cost: 271.14567209446835 Input: [-1.73220707]
# Optimal solution found!
# this is car's states [ 0.82788549 -4.23487784 -1.13682125] [-1.69961979]
# Iteration: 84 Cost: 263.07820947170524 Input: [-1.69961979]
# Optimal solution found!
# this is car's states [ 0.79252192 -4.17751507 -1.14543609] [-1.66729938]
# Iteration: 85 Cost: 255.21189268487555 Input: [-1.66729938]
# Optimal solution found!
# this is car's states [ 0.76081769 -4.11989633 -1.15075809] [-1.63539304]
# Iteration: 86 Cost: 247.54672538811965 Input: [-1.63539304]
# Optimal solution found!
# this is car's states [ 0.73233968 -4.06216649 -1.15316635] [-1.60401642]
# Iteration: 87 Cost: 240.08224270070878 Input: [-1.60401642]
# Optimal solution found!
# this is car's states [ 0.70670073 -4.00445311 -1.15300708] [-1.57325144]
# Iteration: 88 Cost: 232.81746744834155 Input: [-1.57325144]
# Optimal solution found!
# this is car's states [ 0.68355568 -3.94686805 -1.15059541] [-1.54315848]
# Iteration: 89 Cost: 225.7509215895807 Input: [-1.54315848]
# Optimal solution found!
# this is car's states [ 0.66259757 -3.88950892 -1.14621692] [-1.51377646]
# Iteration: 90 Cost: 218.88064102763545 Input: [-1.51377646]
# Optimal solution found!
# this is car's states [ 0.64355419 -3.83246048 -1.14013029] [-1.4851387]
# Iteration: 91 Cost: 212.20421706461502 Input: [-1.4851387]
# Optimal solution found!
# this is car's states [ 0.62618479 -3.77579586 -1.13256771] [-1.4572469]
# Iteration: 92 Cost: 205.71881738751205 Input: [-1.4572469]
# Optimal solution found!
# this is car's states [ 0.61027683 -3.71957787 -1.1237376 ] [-1.43010345]
# Iteration: 93 Cost: 199.42128020430317 Input: [-1.43010345]
# Optimal solution found!
# this is car's states [ 0.5956432  -3.66386001 -1.11382648] [-1.40370215]
# Iteration: 94 Cost: 193.3081404086421 Input: [-1.40370215]
# Optimal solution found!
# this is car's states [ 0.58211956 -3.60868752 -1.10300068] [-1.37803028]
# Iteration: 95 Cost: 187.3756822012975 Input: [-1.37803028]
# Optimal solution found!
# this is car's states [ 0.56956197 -3.5540983  -1.09140805] [-1.35306994]
# Iteration: 96 Cost: 181.61998792898882 Input: [-1.35306994]
# Optimal solution found!
# this is car's states [ 0.5578446  -3.50012371 -1.07917958] [-1.32879941]
# Iteration: 97 Cost: 176.03698423794881 Input: [-1.32879941]
# Optimal solution found!
# this is car's states [ 0.54685769 -3.44678942 -1.06642985] [-1.30517998]
# Iteration: 98 Cost: 170.62248403211441 Input: [-1.30517998]
# Optimal solution found!
# this is car's states [ 0.53650568 -3.39411605 -1.05326227] [-1.28221995]
# Iteration: 99 Cost: 165.37225296330496 Input: [-1.28221995]
# Optimal solution found!
# this is car's states [ 0.52670601 -3.34211966 -1.03976674] [-1.25988176]
# Iteration: 100 Cost: 160.2819437598738 Input: [-1.25988176]
# Optimal solution found!
# this is car's states [ 0.51738718 -3.29081248 -1.02602087] [-1.23812478]
# Iteration: 101 Cost: 155.34721455195015 Input: [-1.23812478]
# Optimal solution found!
# this is car's states [ 0.50848735 -3.24020336 -1.01209291] [-1.21693104]
# Iteration: 102 Cost: 150.5637583770862 Input: [-1.21693104]
# Optimal solution found!
# this is car's states [ 0.49995333 -3.19029824 -0.99804203] [-1.19627331]
# Iteration: 103 Cost: 145.92728036853455 Input: [-1.19627331]
# Optimal solution found!
# this is car's states [ 0.49173944 -3.14110051 -0.98391959] [-1.17612914]
# Iteration: 104 Cost: 141.4335334316463 Input: [-1.17612914]
# Optimal solution found!
# this is car's states [ 0.48380661 -3.09261134 -0.96977001] [-1.15647611]
# Iteration: 105 Cost: 137.0783250111122 Input: [-1.15647611]
# Optimal solution found!
# this is car's states [ 0.4761215  -3.04483005 -0.95563086] [-1.13728442]
# Iteration: 106 Cost: 132.85753018539046 Input: [-1.13728442]
# Optimal solution found!
# this is car's states [ 0.46865562 -2.99775438 -0.9415344 ] [-1.11853489]
# Iteration: 107 Cost: 128.76711599854562 Input: [-1.11853489]
# Optimal solution found!
# this is car's states [ 0.46138481 -2.9513807  -0.92750813] [-1.10020835]
# Iteration: 108 Cost: 124.80313183663995 Input: [-1.10020835]
# Optimal solution found!
# this is car's states [ 0.45428863 -2.90570423 -0.91357524] [-1.0822855]
# Iteration: 109 Cost: 120.96171675639754 Input: [-1.0822855]
# Optimal solution found!
# this is car's states [ 0.44734983 -2.86071924 -0.89975519] [-1.06474811]
# Iteration: 110 Cost: 117.23910567672624 Input: [-1.06474811]
# Optimal solution found!
# this is car's states [ 0.44055389 -2.8164192  -0.88606414] [-1.04757917]
# Iteration: 111 Cost: 113.63163209149985 Input: [-1.04757917]
# Optimal solution found!
# this is car's states [ 0.43388864 -2.77279692 -0.87251537] [-1.0307628]
# Iteration: 112 Cost: 110.13572955556279 Input: [-1.0307628]
# Optimal solution found!
# this is car's states [ 0.4273439  -2.7298447  -0.85911965] [-1.01428356]
# Iteration: 113 Cost: 106.74793226132772 Input: [-1.01428356]
# Optimal solution found!
# this is car's states [ 0.42091119 -2.68755438 -0.8458857 ] [-0.99812918]
# Iteration: 114 Cost: 103.46487603055263 Input: [-0.99812918]
# Optimal solution found!
# this is car's states [ 0.41458345 -2.64591751 -0.83282009] [-0.98228268]
# Iteration: 115 Cost: 100.28329410971065 Input: [-0.98228268]
# Optimal solution found!
# this is car's states [ 0.4083548  -2.60492536 -0.81992839] [-0.96674027]
# Iteration: 116 Cost: 97.20002486899823 Input: [-0.96674027]
# Optimal solution found!
# this is car's states [ 0.40222048 -2.564569   -0.80721441] [-0.95148586]
# Iteration: 117 Cost: 94.21199145270971 Input: [-0.95148586]
# Optimal solution found!
# this is car's states [ 0.3961765  -2.52483939 -0.79468078] [-0.93650907]
# Iteration: 118 Cost: 91.31621968567677 Input: [-0.93650907]
# Optimal solution found!
# this is car's states [ 0.39021954 -2.48572741 -0.78232863] [-0.92179378]
# Iteration: 119 Cost: 88.5098286901711 Input: [-0.92179378]
# Optimal solution found!
# this is car's states [ 0.38434683 -2.44722393 -0.77015953] [-0.90734723]
# Iteration: 120 Cost: 85.79003802832328 Input: [-0.90734723]
# Optimal solution found!
# this is car's states [ 0.3785562  -2.40931975 -0.7581734 ] [-0.89314967]
# Iteration: 121 Cost: 83.15413277189226 Input: [-0.89314967]
# Optimal solution found!
# this is car's states [ 0.37284579 -2.37200573 -0.74637004] [-0.87919926]
# Iteration: 122 Cost: 80.59950003056856 Input: [-0.87919926]
# Optimal solution found!
# this is car's states [ 0.36721411 -2.33527278 -0.73474841] [-0.86548503]
# Iteration: 123 Cost: 78.12360240599394 Input: [-0.86548503]
# Optimal solution found!
# this is car's states [ 0.36165986 -2.29911184 -0.72330721] [-0.85200157]
# Iteration: 124 Cost: 75.72398863357513 Input: [-0.85200157]
# Optimal solution found!
# this is car's states [ 0.35618194 -2.263514   -0.71204462] [-0.83874057]
# Iteration: 125 Cost: 73.39828425809952 Input: [-0.83874057]
# Optimal solution found!
# this is car's states [ 0.35077939 -2.22847039 -0.7009589 ] [-0.82570048]
# Iteration: 126 Cost: 71.14419355081368 Input: [-0.82570048]
# Optimal solution found!
# this is car's states [ 0.3454514  -2.19397229 -0.69004792] [-0.81287366]
# Iteration: 127 Cost: 68.95948874831883 Input: [-0.81287366]
# Optimal solution found!
# this is car's states [ 0.34019722 -2.16001105 -0.67930939] [-0.80025547]
# Iteration: 128 Cost: 66.84201592613613 Input: [-0.80025547]
# Optimal solution found!
# this is car's states [ 0.33501622 -2.12657816 -0.66874167] [-0.78785079]
# Iteration: 129 Cost: 64.78968931968652 Input: [-0.78785079]
# Optimal solution found!
# this is car's states [ 0.32990787 -2.0936652  -0.65834152] [-0.77563659]
# Iteration: 130 Cost: 62.80047760303071 Input: [-0.77563659]
# Optimal solution found!
# this is car's states [ 0.32487153 -2.06126392 -0.64810676] [-0.7636225]
# Iteration: 131 Cost: 60.87243610153334 Input: [-0.7636225]
# Optimal solution found!
# this is car's states [ 0.31990664 -2.02936619 -0.63803425] [-0.75179265]
# Iteration: 132 Cost: 59.003665702825735 Input: [-0.75179265]
# Optimal solution found!
# this is car's states [ 0.31501252 -1.99796404 -0.62812141] [-0.74015016]
# Iteration: 133 Cost: 57.1923411441225 Input: [-0.74015016]
# Optimal solution found!
# this is car's states [ 0.31018857 -1.96704961 -0.61836565] [-0.72869154]
# Iteration: 134 Cost: 55.436687119844876 Input: [-0.72869154]
# Optimal solution found!
# this is car's states [ 0.30543414 -1.93661518 -0.6087644 ] [-0.7174133]
# Iteration: 135 Cost: 53.73498409208473 Input: [-0.7174133]
# Optimal solution found!
# this is car's states [ 0.3007486  -1.90665316 -0.59931508] [-0.7063121]
# Iteration: 136 Cost: 52.085566609043525 Input: [-0.7063121]
# Optimal solution found!
# this is car's states [ 0.2961313  -1.87715607 -0.59001516] [-0.69538473]
# Iteration: 137 Cost: 50.486821515549245 Input: [-0.69538473]
# Optimal solution found!
# this is car's states [ 0.29158158 -1.84811657 -0.58086212] [-0.68462809]
# Iteration: 138 Cost: 48.93718622526889 Input: [-0.68462809]
# Optimal solution found!
# this is car's states [ 0.28709875 -1.81952744 -0.57185348] [-0.67403921]
# Iteration: 139 Cost: 47.43514705352898 Input: [-0.67403921]
# Optimal solution found!
# this is car's states [ 0.28268214 -1.79138159 -0.56298679] [-0.66361521]
# Iteration: 140 Cost: 45.979237612625255 Input: [-0.66361521]
# Optimal solution found!
# this is car's states [ 0.27833103 -1.76367203 -0.55425966] [-0.65335324]
# Iteration: 141 Cost: 44.56803726526513 Input: [-0.65335324]
# Optimal solution found!
# this is car's states [ 0.27404469 -1.73639191 -0.54566972] [-0.6432507]
# Iteration: 142 Cost: 43.20016967786892 Input: [-0.6432507]
# Optimal solution found!
# this is car's states [ 0.2698224  -1.70953449 -0.53721468] [-0.6333049]
# Iteration: 143 Cost: 41.874301237851185 Input: [-0.6333049]
# Optimal solution found!
# this is car's states [ 0.26566342 -1.68309313 -0.52889225] [-0.62351339]
# Iteration: 144 Cost: 40.589139826340045 Input: [-0.62351339]
# Optimal solution found!
# this is car's states [ 0.26156698 -1.65706132 -0.52070022] [-0.61387341]
# Iteration: 145 Cost: 39.343433321372856 Input: [-0.61387341]
# Optimal solution found!
# this is car's states [ 0.25753231 -1.63143265 -0.5126364 ] [-0.60438268]
# Iteration: 146 Cost: 38.13596865713165 Input: [-0.60438268]
# Optimal solution found!
# this is car's states [ 0.25355863 -1.60620082 -0.50469829] [-0.595034]
# Iteration: 147 Cost: 36.96557020529768 Input: [-0.595034]
# Optimal solution found!
# this is car's states [ 0.2496451  -1.58135965 -0.49688427] [-0.58583545]
# Iteration: 148 Cost: 35.83110319496038 Input: [-0.58583545]
# Optimal solution found!
# this is car's states [ 0.24579098 -1.55690303 -0.48919222] [-0.57677828]
# Iteration: 149 Cost: 34.73145854323893 Input: [-0.57677828]
# Optimal solution found!
# this is car's states [ 0.24199549 -1.53282497 -0.48162022] [-0.56786231]
# Iteration: 150 Cost: 33.665567041558106 Input: [-0.56786231]
# Optimal solution found!
# this is car's states [ 0.23825786 -1.50911955 -0.47416633] [-0.55908469]
# Iteration: 151 Cost: 32.63239071340698 Input: [-0.55908469]
# Optimal solution found!
# this is car's states [ 0.23457732 -1.48578097 -0.46682854] [-0.55044166]
# Iteration: 152 Cost: 31.630924129527735 Input: [-0.55044166]
# Optimal solution found!
# this is car's states [ 0.23095308 -1.46280353 -0.45960495] [-0.54193208]
# Iteration: 153 Cost: 30.66019424667489 Input: [-0.54193208]
# Optimal solution found!
# this is car's states [ 0.22738435 -1.4401816  -0.4524937 ] [-0.53355385]
# Iteration: 154 Cost: 29.719257234629545 Input: [-0.53355385]
# Optimal solution found!
# this is car's states [ 0.22387036 -1.41790967 -0.44549297] [-0.52530493]
# Iteration: 155 Cost: 28.80719835191388 Input: [-0.52530493]
# Optimal solution found!
# this is car's states [ 0.22041032 -1.39598229 -0.43860097] [-0.51718332]
# Iteration: 156 Cost: 27.923131022193825 Input: [-0.51718332]
# Optimal solution found!
# this is car's states [ 0.21700344 -1.37439412 -0.43181596] [-0.50918709]
# Iteration: 157 Cost: 27.06619596893645 Input: [-0.50918709]
# Optimal solution found!
# this is car's states [ 0.21364897 -1.35313989 -0.42513625] [-0.50131452]
# Iteration: 158 Cost: 26.23556031498265 Input: [-0.50131452]
# Optimal solution found!
# this is car's states [ 0.21034612 -1.33221443 -0.41856015] [-0.49356359]
# Iteration: 159 Cost: 25.43041662549776 Input: [-0.49356359]
# Optimal solution found!
# this is car's states [ 0.20777668 -1.30163499 -0.41120741] [-0.47427863]
# Iteration: 160 Cost: 24.25776181862334 Input: [-0.47427863]
# Optimal solution found!
# this is car's states [ 0.20550054 -1.27145764 -0.40325032] [-0.45621808]
# Iteration: 161 Cost: 23.13438737669735 Input: [-0.45621808]
# Optimal solution found!
# this is car's states [ 0.20342888 -1.24170466 -0.39483432] [-0.43926079]
# Iteration: 162 Cost: 22.058184591165407 Input: [-0.43926079]
# Optimal solution found!
# this is car's states [ 0.20149033 -1.21239231 -0.3860817 ] [-0.42329868]
# Iteration: 163 Cost: 21.027134320497414 Input: [-0.42329868]
# Optimal solution found!
# this is car's states [ 0.1996282  -1.18353182 -0.37709477] [-0.40823369]
# Iteration: 164 Cost: 20.039303677643815 Input: [-0.40823369]
# Optimal solution found!
# this is car's states [ 0.19779817 -1.15513023 -0.36795861] [-0.39397719]
# Iteration: 165 Cost: 19.092844693703146 Input: [-0.39397719]
# Optimal solution found!
# this is car's states [ 0.19596617 -1.12719111 -0.35874347] [-0.38044842]
# Iteration: 166 Cost: 18.185992822129084 Input: [-0.38044842]
# Optimal solution found!
# this is car's states [ 0.19410668 -1.09971524 -0.34950693] [-0.36757567]
# Iteration: 167 Cost: 17.317065678753067 Input: [-0.36757567]
# Optimal solution found!
# this is car's states [ 0.1922012  -1.07270108 -0.34029577] [-0.35529417]
# Iteration: 168 Cost: 16.48446027576868 Input: [-0.35529417]
# Optimal solution found!
# this is car's states [ 0.19023697 -1.04614524 -0.33114767] [-0.34354688]
# Iteration: 169 Cost: 15.686650772662317 Input: [-0.34354688]
# Optimal solution found!
# this is car's states [ 0.18820591 -1.0200429  -0.32209244] [-0.33228139]
# Iteration: 170 Cost: 14.922185143633131 Input: [-0.33228139]
# Optimal solution found!
# this is car's states [ 0.18610368 -0.99438808 -0.31315338] [-0.32145155]
# Iteration: 171 Cost: 14.189682917635782 Input: [-0.32145155]
# Optimal solution found!
# this is car's states [ 0.18392889 -0.96917396 -0.30434825] [-0.31101625]
# Iteration: 172 Cost: 13.487831566576268 Input: [-0.31101625]
# Optimal solution found!
# this is car's states [ 0.18168245 -0.94439306 -0.29569026] [-0.30093902]
# Iteration: 173 Cost: 12.815383176031206 Input: [-0.30093902]
# Optimal solution found!
# this is car's states [ 0.17936705 -0.92003746 -0.2871888 ] [-0.29118725]
# Iteration: 174 Cost: 12.171151001029083 Input: [-0.29118725]
# Optimal solution found!
# this is car's states [ 0.17698667 -0.89609895 -0.2788501 ] [-0.28173217]
# Iteration: 175 Cost: 11.554006216922794 Input: [-0.28173217]
# Optimal solution found!
# this is car's states [ 0.17454625 -0.87256914 -0.27067789] [-0.27254871]
# Iteration: 176 Cost: 10.962874530706813 Input: [-0.27254871]
# Optimal solution found!
# this is car's states [ 0.17205135 -0.84943958 -0.26267381] [-0.26361454]
# Iteration: 177 Cost: 10.396732805523571 Input: [-0.26361454]
# Optimal solution found!
# this is car's states [ 0.16950794 -0.82670181 -0.25483785] [-0.2549099]
# Iteration: 178 Cost: 9.854606065120754 Input: [-0.2549099]
# Optimal solution found!
# this is car's states [ 0.16692217 -0.80434747 -0.24716869] [-0.24641737]
# Iteration: 179 Cost: 9.33556459598073 Input: [-0.24641737]
# Optimal solution found!
# this is car's states [ 0.16430024 -0.78236831 -0.23966398] [-0.23812162]
# Iteration: 180 Cost: 8.838721154734015 Input: [-0.23812162]
# Optimal solution found!
# this is car's states [ 0.16164825 -0.76075624 -0.2323206 ] [-0.23000914]
# Iteration: 181 Cost: 8.363228361042452 Input: [-0.23000914]
# Optimal solution found!
# this is car's states [ 0.15897215 -0.73950336 -0.22513515] [-0.22207199]
# Iteration: 182 Cost: 7.908276246366248 Input: [-0.22207199]
# Optimal solution found!
# this is car's states [ 0.15627769 -0.71860196 -0.21810328] [-0.21429274]
# Iteration: 183 Cost: 7.47308865620521 Input: [-0.21429274]
# Optimal solution found!
# this is car's states [ 0.15357022 -0.6980446  -0.21122052] [-0.20666421]
# Iteration: 184 Cost: 7.05692482016841 Input: [-0.20666421]
# Optimal solution found!
# this is car's states [ 0.1508548  -0.67782403 -0.20448252] [-0.19918157]
# Iteration: 185 Cost: 6.659074314808903 Input: [-0.19918157]
# Optimal solution found!
# this is car's states [ 0.14813614 -0.65793324 -0.19788455] [-0.1918339]
# Iteration: 186 Cost: 6.27885494222096 Input: [-0.1918339]
# Optimal solution found!
# this is car's states [ 0.14541859 -0.63836546 -0.19142204] [-0.18461712]
# Iteration: 187 Cost: 5.9156132079211385 Input: [-0.18461712]
# Optimal solution found!
# this is car's states [ 0.14270608 -0.61911416 -0.18508992] [-0.17751792]
# Iteration: 188 Cost: 5.568720971275224 Input: [-0.17751792]
# Optimal solution found!
# this is car's states [ 0.14000224 -0.60017303 -0.17888535] [-0.17055926]
# Iteration: 189 Cost: 5.237576739216988 Input: [-0.17055926]
# Optimal solution found!
# this is car's states [ 0.13731054 -0.58153588 -0.17280306] [-0.16370499]
# Iteration: 190 Cost: 4.9215949913114265 Input: [-0.16370499]
# Optimal solution found!
# this is car's states [ 0.13463388 -0.56319683 -0.16683898] [-0.15696371]
# Iteration: 191 Cost: 4.620220561080608 Input: [-0.15696371]
# Optimal solution found!
# this is car's states [ 0.13197487 -0.54515019 -0.16098851] [-0.15032304]
# Iteration: 192 Cost: 4.33291603479867 Input: [-0.15032304]
# Optimal solution found!
# this is car's states [ 0.12933588 -0.52739044 -0.1552501 ] [-0.14381693]
# Iteration: 193 Cost: 4.059165917578826 Input: [-0.14381693]
# Optimal solution found!
# this is car's states [ 0.12671922 -0.50991216 -0.14961764] [-0.13738285]
# Iteration: 194 Cost: 3.7984655824620206 Input: [-0.13738285]
# Optimal solution found!
# this is car's states [ 0.1241265  -0.49271025 -0.14408928] [-0.13106896]
# Iteration: 195 Cost: 3.5503413528005474 Input: [-0.13106896]
# Optimal solution found!
# this is car's states [ 0.12155943 -0.47577966 -0.1386607 ] [-0.12483993]
# Iteration: 196 Cost: 3.3143262487012595 Input: [-0.12483993]
# Optimal solution found!
# this is car's states [ 0.11901925 -0.45911559 -0.13332923] [-0.11871198]
# Iteration: 197 Cost: 3.089976338957556 Input: [-0.11871198]
# Optimal solution found!
# this is car's states [ 0.11650714 -0.4427133  -0.128092  ] [-0.11267852]
# Iteration: 198 Cost: 2.8768599588177555 Input: [-0.11267852]
# Optimal solution found!
# this is car's states [ 0.11402409 -0.42656823 -0.12294629] [-0.10673772]
# Iteration: 199 Cost: 2.674561458302717 Input: [-0.10673772]
# Optimal solution found!
# this is car's states [ 0.11157088 -0.41067594 -0.11788931] [-0.10088495]
# Iteration: 200 Cost: 2.482679707748668 Input: [-0.10088495]
# Optimal solution found!
# this is car's states [ 0.10914814 -0.39503212 -0.11291893] [-0.09512513]
# Iteration: 201 Cost: 2.300827943233502 Input: [-0.09512513]
# Optimal solution found!
# this is car's states [ 0.10675641 -0.37963255 -0.10803267] [-0.08945074]
# Iteration: 202 Cost: 2.128631829706667 Input: [-0.08945074]
# Optimal solution found!
# this is car's states [ 0.10439607 -0.36447314 -0.10322857] [-0.08386539]
# Iteration: 203 Cost: 1.965730776530696 Input: [-0.08386539]
# Optimal solution found!
# this is car's states [ 0.10206742 -0.34954989 -0.09850436] [-0.07836188]
# Iteration: 204 Cost: 1.8117759294075222 Input: [-0.07836188]
# Optimal solution found!
# this is car's states [ 0.09977062 -0.33485889 -0.09385813] [-0.07294249]
# Iteration: 205 Cost: 1.6664310892042757 Input: [-0.07294249]
# Optimal solution found!
# this is car's states [ 0.09750578 -0.32039636 -0.08928818] [-0.06760688]
# Iteration: 206 Cost: 1.5293711109822772 Input: [-0.06760688]
# Optimal solution found!
# this is car's states [ 0.09527293 -0.30615855 -0.08479279] [-0.06235262]
# Iteration: 207 Cost: 1.4002818706759337 Input: [-0.06235262]
# Optimal solution found!
# this is car's states [ 0.09307204 -0.29214182 -0.08037021] [-0.05717724]
# Iteration: 208 Cost: 1.2788600892781148 Input: [-0.05717724]
# Optimal solution found!
# this is car's states [ 0.09090299 -0.27834263 -0.07601883] [-0.05207984]
# Iteration: 209 Cost: 1.1648129203908286 Input: [-0.05207984]
# Optimal solution found!
# this is car's states [ 0.08876563 -0.26475748 -0.07173731] [-0.04706191]
# Iteration: 210 Cost: 1.0578574443553261 Input: [-0.04706191]
# Optimal solution found!
# this is car's states [ 0.08665979 -0.25138295 -0.06752413] [-0.04211929]
# Iteration: 211 Cost: 0.9577201929431114 Input: [-0.04211929]
# Optimal solution found!
# this is car's states [ 0.0845852  -0.2382157  -0.06337796] [-0.03725227]
# Iteration: 212 Cost: 0.8641372172578158 Input: [-0.03725227]
# Optimal solution found!
# this is car's states [ 0.08254163 -0.22525244 -0.05929751] [-0.03245998]
# Iteration: 213 Cost: 0.7768534666798241 Input: [-0.03245998]
# Optimal solution found!
# this is car's states [ 0.08052876 -0.21248995 -0.05528139] [-0.02773873]
# Iteration: 214 Cost: 0.6956225824428464 Input: [-0.02773873]
# Optimal solution found!
# this is car's states [ 0.07854628 -0.19992507 -0.05132864] [-0.02309275]
# Iteration: 215 Cost: 0.6202067008599508 Input: [-0.02309275]
# Optimal solution found!
# this is car's states [ 0.07659387 -0.18755469 -0.04743806] [-0.01851751]
# Iteration: 216 Cost: 0.5503759021878643 Input: [-0.01851751]
# Optimal solution found!
# this is car's states [ 0.0746712  -0.17537576 -0.04360857] [-0.01401266]
# Iteration: 217 Cost: 0.48590827041993684 Input: [-0.01401266]
# Optimal solution found!
# this is car's states [ 0.07277792 -0.16338529 -0.03983889] [-0.00957457]
# Iteration: 218 Cost: 0.42658947623036714 Input: [-0.00957457]
# Optimal solution found!
# this is car's states [ 0.07091361 -0.15158033 -0.03612804] [-0.00520494]
# Iteration: 219 Cost: 0.3722125564096497 Input: [-0.00520494]
# Optimal solution found!
# this is car's states [ 0.06907789 -0.139958   -0.032475  ] [-0.00090228]
# Iteration: 220 Cost: 0.32257760706687766 Input: [-0.00090228]
# Optimal solution found!
# this is car's states [ 0.06727039 -0.12851545 -0.02887892] [0.00333273]
# Iteration: 221 Cost: 0.2774916092714293 Input: [0.00333273]
# Optimal solution found!
# this is car's states [ 0.06549073 -0.11724988 -0.02533877] [0.00750355]
# Iteration: 222 Cost: 0.23676822858014338 Input: [0.00750355]
# Optimal solution found!
# this is car's states [ 0.06374371 -0.10615683 -0.02192147] [0.01071027]
# Iteration: 223 Cost: 0.20021277599308068 Input: [0.01071027]
# Optimal solution found!
# this is car's states [ 0.06204474 -0.09522847 -0.01862798] [0.01373672]
# Iteration: 224 Cost: 0.1676479300192758 Input: [0.01373672]
# Optimal solution found!
# this is car's states [ 0.0604033  -0.08445905 -0.01544015] [0.0168345]
# Iteration: 225 Cost: 0.13892870291306597 Input: [0.0168345]
# Optimal solution found!
# this is car's states [ 0.05882512 -0.07384414 -0.01234251] [0.01999311]
# Iteration: 226 Cost: 0.11391133093402205 Input: [0.01999311]
# Optimal solution found!
# this is car's states [ 0.05731418 -0.06337993 -0.00932205] [0.02320121]
# Iteration: 227 Cost: 0.09245593327249622 Input: [0.02320121]
# Optimal solution found!
# this is car's states [ 0.05587297 -0.05306317 -0.00636757] [0.02645246]
# Iteration: 228 Cost: 0.07442625447128014 Input: [0.02645246]
# Optimal solution found!
# this is car's states [ 0.05450269 -0.04289108 -0.00346982] [0.02973606]
# Iteration: 229 Cost: 0.05968922881856998 Input: [0.02973606]
# Optimal solution found!
# this is car's states [ 0.05320355 -0.03286122 -0.00062112] [0.03304428]
# Iteration: 230 Cost: 0.04811501524977586 Input: [0.03304428]
# Optimal solution found!
# this is car's states [ 0.0519749  -0.02297152  0.00218489] [0.03636968]
# Iteration: 231 Cost: 0.03957678003139316 Input: [0.03636968]
# Optimal solution found!
# this is car's states [ 0.05081542 -0.01322011  0.00495338] [0.03970537]
# Iteration: 232 Cost: 0.03395062837971533 Input: [0.03970537]
# Optimal solution found!
# this is car's states [ 0.04972326 -0.00360535  0.00768852] [0.04304506]
# Iteration: 233 Cost: 0.031115552892507527 Input: [0.04304506]
# Optimal solution found!
# this is car's states [0.04869615 0.00587423 0.0103936 ] [0.04638294]
# Iteration: 234 Cost: 0.03095340166997271 Input: [0.04638294]
# Optimal solution found!
# this is car's states [0.04773149 0.01522    0.01307118] [0.04971364]
# Iteration: 235 Cost: 0.03334887047467266 Input: [0.04971364]
# Optimal solution found!
# this is car's states [0.04682649 0.02443321 0.0157232 ] [0.05303249]
# Iteration: 236 Cost: 0.0381895116576138 Input: [0.05303249]
# Optimal solution found!
# this is car's states [0.04597819 0.03351506 0.01835108] [0.05633529]
# Iteration: 237 Cost: 0.04536572086325377 Input: [0.05633529]
# Optimal solution found!
# this is car's states [0.04518354 0.0424667  0.02095581] [0.05961825]
# Iteration: 238 Cost: 0.05477074646040525 Input: [0.05961825]
# Optimal solution found!
# this is car's states [0.04443949 0.05128925 0.02353804] [0.06287811]
# Iteration: 239 Cost: 0.06630069741679212 Input: [0.06287811]
# Optimal solution found!
# this is car's states [0.04374295 0.0599838  0.0260981 ] [0.06611182]
# Iteration: 240 Cost: 0.07985453649419222 Input: [0.06611182]
# Optimal solution found!
# this is car's states [0.0430909  0.06855145 0.02863612] [0.06931674]
# Iteration: 241 Cost: 0.09533410124792693 Input: [0.06931674]
# Optimal solution found!
# this is car's states [0.04248038 0.07699331 0.03115201] [0.07249052]
# Iteration: 242 Cost: 0.11264410256439734 Input: [0.07249052]
# Optimal solution found!
# this is car's states [0.04190852 0.08531048 0.03364555] [0.07563109]
# Iteration: 243 Cost: 0.13169212045762232 Input: [0.07563109]
# Optimal solution found!
# this is car's states [0.04137257 0.0935041  0.03611643] [0.07873688]
# Iteration: 244 Cost: 0.15238860344818253 Input: [0.07873688]
# Optimal solution found!
# this is car's states [0.04086989 0.10157533 0.03856423] [0.0818064]
# Iteration: 245 Cost: 0.1746468253300209 Input: [0.0818064]
# Optimal solution found!
# this is car's states [0.04039798 0.10952532 0.04098851] [0.08483837]
# Iteration: 246 Cost: 0.19838288315124575 Input: [0.08483837]
# Optimal solution found!
# this is car's states [0.03995446 0.1173553  0.04338878] [0.08783179]
# Iteration: 247 Cost: 0.2235156740708681 Input: [0.08783179]
# Optimal solution found!
# this is car's states [0.0395371  0.12506647 0.04576454] [0.09078579]
# Iteration: 248 Cost: 0.2499668577643258 Input: [0.09078579]
# Optimal solution found!
# this is car's states [0.03914379 0.13266009 0.04811531] [0.0936998]
# Iteration: 249 Cost: 0.2776608294374586 Input: [0.0936998]
# Optimal solution found!
# this is car's states [0.03877258 0.14013743 0.05044059] [0.09657326]
# Iteration: 250 Cost: 0.30652465881717395 Input: [0.09657326]
# Optimal solution found!
# this is car's states [0.03842165 0.1474998  0.05273994] [0.09940585]
# Iteration: 251 Cost: 0.3364880646410528 Input: [0.09940585]
# Optimal solution found!
# this is car's states [0.0380893  0.15474851 0.05501292] [0.10219736]
# Iteration: 252 Cost: 0.3674833528694085 Input: [0.10219736]
# Optimal solution found!
# this is car's states [0.03777397 0.16188489 0.05725915] [0.10494768]
# Iteration: 253 Cost: 0.39944536464606806 Input: [0.10494768]
# Optimal solution found!
# this is car's states [0.0374742  0.16891031 0.05947828] [0.10765681]
# Iteration: 254 Cost: 0.43231142059634675 Input: [0.10765681]
# Optimal solution found!
# this is car's states [0.03718867 0.17582614 0.06167   ] [0.11032484]
# Iteration: 255 Cost: 0.4660212628481545 Input: [0.11032484]
# Optimal solution found!
# this is car's states [0.03691615 0.18263376 0.06383404] [0.11295192]
# Iteration: 256 Cost: 0.5005169898866387 Input: [0.11295192]
# Optimal solution found!
# this is car's states [0.03665553 0.18933456 0.06597019] [0.11553827]
# Iteration: 257 Cost: 0.535743000505204 Input: [0.11553827]
# Optimal solution found!
# this is car's states [0.03640578 0.19592996 0.06807826] [0.11808418]
# Iteration: 258 Cost: 0.5716459281770426 Input: [0.11808418]
# Optimal solution found!
# this is car's states [0.03616598 0.20242136 0.07015814] [0.12058998]
# Iteration: 259 Cost: 0.6081745765557525 Input: [0.12058998]
# Optimal solution found!
# this is car's states [0.03593527 0.20881018 0.07220971] [0.12305604]
# Iteration: 260 Cost: 0.6452798550311211 Input: [0.12305604]
# Optimal solution found!
# this is car's states [0.0357129  0.21509784 0.07423295] [0.12548278]
# Iteration: 261 Cost: 0.6829147131198963 Input: [0.12548278]
# Optimal solution found!
# this is car's states [0.03549815 0.22128575 0.07622782] [0.12787058]
# Iteration: 262 Cost: 0.7210340756169277 Input: [0.12787058]
# Optimal solution found!
# this is car's states [0.03529042 0.22737534 0.07819435] [0.13021987]
# Iteration: 263 Cost: 0.7595947919928133 Input: [0.13021987]
# Optimal solution found!
# this is car's states [0.03508912 0.23336802 0.0801326 ] [0.13253138]
# Iteration: 264 Cost: 0.7985555696861857 Input: [0.13253138]
# Optimal solution found!
# this is car's states [0.03489376 0.23926519 0.08204268] [0.1348056]
# Iteration: 265 Cost: 0.8378768521430828 Input: [0.1348056]
# Optimal solution found!
# this is car's states [0.03470387 0.24506827 0.08392471] [0.13704292]
# Iteration: 266 Cost: 0.8775208031280193 Input: [0.13704292]
# Optimal solution found!
# this is car's states [0.03451903 0.25077864 0.08577884] [0.1392439]
# Iteration: 267 Cost: 0.9174512753502402 Input: [0.1392439]
# Optimal solution found!
# this is car's states [0.03433888 0.2563977  0.08760523] [0.14140901]
# Iteration: 268 Cost: 0.9576337141663347 Input: [0.14140901]
# Optimal solution found!
# this is car's states [0.0341631  0.26192682 0.08940408] [0.14353877]
# Iteration: 269 Cost: 0.998035130489554 Input: [0.14353877]
# Optimal solution found!
# this is car's states [0.03399137 0.26736736 0.09117563] [0.14563399]
# Iteration: 270 Cost: 1.0386240255604025 Input: [0.14563399]
# Optimal solution found!
# this is car's states [0.03382344 0.27272069 0.09292011] [0.14769525]
# Iteration: 271 Cost: 1.079370274382951 Input: [0.14769525]
# Optimal solution found!
# this is car's states [0.03365908 0.27798815 0.0946378 ] [0.14972306]
# Iteration: 272 Cost: 1.1202451097639246 Input: [0.14972306]
# Optimal solution found!
# this is car's states [0.03349805 0.28317105 0.09632893] [0.15171734]
# Iteration: 273 Cost: 1.161221095956639 Input: [0.15171734]
# Optimal solution found!
# this is car's states [0.03334019 0.28827071 0.09799373] [0.15367829]
# Iteration: 274 Cost: 1.2022722277696731 Input: [0.15367829]
# Optimal solution found!
# this is car's states [0.03318535 0.29328845 0.09963254] [0.15560797]
# Iteration: 275 Cost: 1.2433738334566158 Input: [0.15560797]
# Optimal solution found!
# this is car's states [0.03303335 0.29822554 0.10124567] [0.15750623]
# Iteration: 276 Cost: 1.2845020442582797 Input: [0.15750623]
# Optimal solution found!
# this is car's states [0.03288409 0.30308324 0.10283344] [0.15937355]
# Iteration: 277 Cost: 1.3256342811079884 Input: [0.15937355]
# Optimal solution found!
# this is car's states [0.03273743 0.30786282 0.10439617] [0.16121042]
# Iteration: 278 Cost: 1.3667490655337566 Input: [0.16121042]
# Optimal solution found!
# this is car's states [0.03259328 0.3125655  0.10593417] [0.16301735]
# Iteration: 279 Cost: 1.4078259704522118 Input: [0.16301735]
# Optimal solution found!
# this is car's states [0.03245154 0.31719252 0.10744777] [0.16479483]
# Iteration: 280 Cost: 1.4488455799731712 Input: [0.16479483]
# Optimal solution found!
# this is car's states [0.03231213 0.32174506 0.10893731] [0.16654337]
# Iteration: 281 Cost: 1.4897894464026473 Input: [0.16654337]
# Optimal solution found!
# this is car's states [0.03217498 0.32622432 0.11040311] [0.16826344]
# Iteration: 282 Cost: 1.5306400525555661 Input: [0.16826344]
# Optimal solution found!
# this is car's states [0.03204001 0.33063147 0.1118455 ] [0.16995552]
# Iteration: 283 Cost: 1.571380775385164 Input: [0.16995552]
# Optimal solution found!
# this is car's states [0.03190717 0.33496766 0.11326484] [0.17162009]
# Iteration: 284 Cost: 1.6119958495461753 Input: [0.17162009]
# Optimal solution found!
# this is car's states [0.03177642 0.33923403 0.11466145] [0.17325761]
# Iteration: 285 Cost: 1.6524703339112654 Input: [0.17325761]
# Optimal solution found!
# this is car's states [0.03164769 0.3434317  0.11603566] [0.17486854]
# Iteration: 286 Cost: 1.6927900783616476 Input: [0.17486854]
# Optimal solution found!
# this is car's states [0.03152095 0.34756177 0.11738782] [0.17645333]
# Iteration: 287 Cost: 1.7329416916287186 Input: [0.17645333]
# Optimal solution found!
# this is car's states [0.03139616 0.35162532 0.11871825] [0.1780124]
# Iteration: 288 Cost: 1.772912512954186 Input: [0.1780124]
# Optimal solution found!
# this is car's states [0.03127327 0.35562343 0.1200273 ] [0.1795462]
# Iteration: 289 Cost: 1.81269058219233 Input: [0.1795462]
# Optimal solution found!
# this is car's states [0.03115226 0.35955715 0.12131528] [0.18105515]
# Iteration: 290 Cost: 1.8522646115554982 Input: [0.18105515]
# Optimal solution found!
# this is car's states [0.0310331  0.36342752 0.12258252] [0.18253965]
# Iteration: 291 Cost: 1.891623959564337 Input: [0.18253965]
# Optimal solution found!
# this is car's states [0.03091576 0.36723555 0.12382935] [0.18400013]
# Iteration: 292 Cost: 1.930758604832568 Input: [0.18400013]
# Optimal solution found!
# this is car's states [0.0308002  0.37098225 0.1250561 ] [0.185437]
# Iteration: 293 Cost: 1.969659116055362 Input: [0.185437]
# Optimal solution found!
# this is car's states [0.03068641 0.37466861 0.12626307] [0.18685065]
# Iteration: 294 Cost: 2.008316629243741 Input: [0.18685065]
# Optimal solution found!
# this is car's states [0.03057435 0.3782956  0.12745059] [0.18824146]
# Iteration: 295 Cost: 2.0467228286922823 Input: [0.18824146]
# Optimal solution found!
# this is car's states [0.030464   0.38186419 0.12861896] [0.1896098]
# Iteration: 296 Cost: 2.0848699251542153 Input: [0.1896098]
# Optimal solution found!
# this is car's states [0.03035534 0.3853753  0.12976849] [0.19095604]
# Iteration: 297 Cost: 2.1227506346376366 Input: [0.19095604]
# Optimal solution found!
# this is car's states [0.03024835 0.38882987 0.13089948] [0.19228054]
# Iteration: 298 Cost: 2.160358157869293 Input: [0.19228054]
# Optimal solution found!
# this is car's states [0.03014299 0.39222881 0.13201223] [0.19358364]
# Iteration: 299 Cost: 2.197686160728091 Input: [0.19358364]
# Optimal solution found!
# this is car's states [0.02933855 0.38558936 0.13246516] [0.18635215]
# Iteration: 300 Cost: 2.1146365858358576 Input: [0.18635215]
# Optimal solution found!
# this is car's states [0.0282255  0.37895772 0.13235728] [0.17953237]
# Iteration: 301 Cost: 2.034687313085947 Input: [0.17953237]
# Optimal solution found!
# this is car's states [0.02687624 0.3723573  0.13177616] [0.17310817]
# Iteration: 302 Cost: 1.9578334642048694 Input: [0.17310817]
# Optimal solution found!
# this is car's states [0.02535253 0.36580763 0.13079908] [0.1670623]
# Iteration: 303 Cost: 1.884044286596959 Input: [0.1670623]
# Optimal solution found!
# this is car's states [0.02370672 0.35932487 0.12949405] [0.16137774]
# Iteration: 304 Cost: 1.8132672582391376 Input: [0.16137774]
# Optimal solution found!
# this is car's states [0.02198286 0.35292226 0.12792053] [0.15603362]
# Iteration: 305 Cost: 1.7454318618591709 Input: [0.15603362]
# Optimal solution found!
# this is car's states [0.02021774 0.34661042 0.12613054] [0.1510129]
# Iteration: 306 Cost: 1.6804542647360738 Input: [0.1510129]
# Optimal solution found!
# this is car's states [0.01844177 0.34039775 0.12416931] [0.14629628]
# Iteration: 307 Cost: 1.6182397303750837 Input: [0.14629628]
# Optimal solution found!
# this is car's states [0.01667982 0.33429071 0.12207587] [0.14186336]
# ...
# Problem is infeasible.
# No solution 172
# this is car's states [-2.34807168 -0.35913902  0.07007589] [0.09573209]
# Iteration: 497 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 173
# this is car's states [-2.3768028  -0.36264282  0.07007589] [0.09573209]
# Iteration: 498 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 174
# this is car's states [-2.40570911 -0.36614661  0.07007589] [0.09573209]
# Iteration: 499 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 175
# this is car's states [-2.43479061 -0.36965041  0.07007589] [0.09573209]
# Iteration: 500 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 176
# this is car's states [-2.4640473  -0.3731542   0.07007589] [0.09573209]
# Iteration: 501 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 177
# this is car's states [-2.49347918 -0.376658    0.07007589] [0.09573209]
# Iteration: 502 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 178
# this is car's states [-2.52308625 -0.38016179  0.07007589] [0.09573209]
# Iteration: 503 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 179
# this is car's states [-2.55286851 -0.38366559  0.07007589] [0.09573209]
# Iteration: 504 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 180
# this is car's states [-2.58282595 -0.38716938  0.07007589] [0.09573209]
# Iteration: 505 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 181
# this is car's states [-2.61295859 -0.39067317  0.07007589] [0.09573209]
# Iteration: 506 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 182
# this is car's states [-2.64326642 -0.39417697  0.07007589] [0.09573209]
# Iteration: 507 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 183
# this is car's states [-2.67374944 -0.39768076  0.07007589] [0.09573209]
# Iteration: 508 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 184
# this is car's states [-2.70440764 -0.40118456  0.07007589] [0.09573209]
# Iteration: 509 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 185
# this is car's states [-2.73524104 -0.40468835  0.07007589] [0.09573209]
# Iteration: 510 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 186
# this is car's states [-2.76624963 -0.40819215  0.07007589] [0.09573209]
# Iteration: 511 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 187
# this is car's states [-2.7974334  -0.41169594  0.07007589] [0.09573209]
# Iteration: 512 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 188
# this is car's states [-2.82879237 -0.41519974  0.07007589] [0.09573209]
# Iteration: 513 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 189
# this is car's states [-2.86032652 -0.41870353  0.07007589] [0.09573209]
# Iteration: 514 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 190
# this is car's states [-2.89203587 -0.42220733  0.07007589] [0.09573209]
# Iteration: 515 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 191
# this is car's states [-2.9239204  -0.42571112  0.07007589] [0.09573209]
# Iteration: 516 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 192
# this is car's states [-2.95598013 -0.42921492  0.07007589] [0.09573209]
# Iteration: 517 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 193
# this is car's states [-2.98821504 -0.43271871  0.07007589] [0.09573209]
# Iteration: 518 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 194
# this is car's states [-3.02062515 -0.43622251  0.07007589] [0.09573209]
# Iteration: 519 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 195
# this is car's states [-3.05321044 -0.4397263   0.07007589] [0.09573209]
# Iteration: 520 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 196
# this is car's states [-3.08597092 -0.44323009  0.07007589] [0.09573209]
# Iteration: 521 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 197
# this is car's states [-3.1189066  -0.44673389  0.07007589] [0.09573209]
# Iteration: 522 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 198
# this is car's states [-3.15201746 -0.45023768  0.07007589] [0.09573209]
# Iteration: 523 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 199
# this is car's states [-3.18530351 -0.45374148  0.07007589] [0.09573209]
# Iteration: 524 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 200
# this is car's states [-3.21876475 -0.45724527  0.07007589] [0.09573209]
# Iteration: 525 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 201
# this is car's states [-3.25240119 -0.46074907  0.07007589] [0.09573209]
# Iteration: 526 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 202
# this is car's states [-3.28621281 -0.46425286  0.07007589] [0.09573209]
# Iteration: 527 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 203
# this is car's states [-3.32019962 -0.46775666  0.07007589] [0.09573209]
# Iteration: 528 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 204
# this is car's states [-3.35436162 -0.47126045  0.07007589] [0.09573209]
# Iteration: 529 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 205
# this is car's states [-3.38869881 -0.47476425  0.07007589] [0.09573209]
# Iteration: 530 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 206
# this is car's states [-3.42321119 -0.47826804  0.07007589] [0.09573209]
# Iteration: 531 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 207
# this is car's states [-3.45789876 -0.48177184  0.07007589] [0.09573209]
# Iteration: 532 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 208
# this is car's states [-3.49276152 -0.48527563  0.07007589] [0.09573209]
# Iteration: 533 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 209
# this is car's states [-3.52779947 -0.48877942  0.07007589] [0.09573209]
# Iteration: 534 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 210
# this is car's states [-3.56301261 -0.49228322  0.07007589] [0.09573209]
# Iteration: 535 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 211
# this is car's states [-3.59840094 -0.49578701  0.07007589] [0.09573209]
# Iteration: 536 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 212
# this is car's states [-3.63396446 -0.49929081  0.07007589] [0.09573209]
# Iteration: 537 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 213
# this is car's states [-3.66970317 -0.5027946   0.07007589] [0.09573209]
# Iteration: 538 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 214
# this is car's states [-3.70561707 -0.5062984   0.07007589] [0.09573209]
# Iteration: 539 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 215
# this is car's states [-3.74170616 -0.50980219  0.07007589] [0.09573209]
# Iteration: 540 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 216
# this is car's states [-3.77797044 -0.51330599  0.07007589] [0.09573209]
# Iteration: 541 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 217
# this is car's states [-3.8144099  -0.51680978  0.07007589] [0.09573209]
# Iteration: 542 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 218
# this is car's states [-3.85102456 -0.52031358  0.07007589] [0.09573209]
# Iteration: 543 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 219
# this is car's states [-3.88781441 -0.52381737  0.07007589] [0.09573209]
# Iteration: 544 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 220
# this is car's states [-3.92477945 -0.52732117  0.07007589] [0.09573209]
# Iteration: 545 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 221
# this is car's states [-3.96191967 -0.53082496  0.07007589] [0.09573209]
# Iteration: 546 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 222
# this is car's states [-3.99923509 -0.53432876  0.07007589] [0.09573209]
# Iteration: 547 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 223
# this is car's states [-4.0367257  -0.53783255  0.07007589] [0.09573209]
# Iteration: 548 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 224
# this is car's states [-4.07439149 -0.54133634  0.07007589] [0.09573209]
# Iteration: 549 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 225
# this is car's states [-4.11223248 -0.54484014  0.07007589] [0.09573209]
# Iteration: 550 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 226
# this is car's states [-4.15024865 -0.54834393  0.07007589] [0.09573209]
# Iteration: 551 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 227
# this is car's states [-4.18844002 -0.55184773  0.07007589] [0.09573209]
# Iteration: 552 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 228
# this is car's states [-4.22680657 -0.55535152  0.07007589] [0.09573209]
# Iteration: 553 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 229
# this is car's states [-4.26534832 -0.55885532  0.07007589] [0.09573209]
# Iteration: 554 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 230
# this is car's states [-4.30406525 -0.56235911  0.07007589] [0.09573209]
# Iteration: 555 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 231
# this is car's states [-4.34295738 -0.56586291  0.07007589] [0.09573209]
# Iteration: 556 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 232
# this is car's states [-4.38202469 -0.5693667   0.07007589] [0.09573209]
# Iteration: 557 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 233
# this is car's states [-4.42126719 -0.5728705   0.07007589] [0.09573209]
# Iteration: 558 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 234
# this is car's states [-4.46068489 -0.57637429  0.07007589] [0.09573209]
# Iteration: 559 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 235
# this is car's states [-4.50027777 -0.57987809  0.07007589] [0.09573209]
# Iteration: 560 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 236
# this is car's states [-4.54004584 -0.58338188  0.07007589] [0.09573209]
# Iteration: 561 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 237
# this is car's states [-4.57998911 -0.58688567  0.07007589] [0.09573209]
# Iteration: 562 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 238
# this is car's states [-4.62010756 -0.59038947  0.07007589] [0.09573209]
# Iteration: 563 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 239
# this is car's states [-4.6604012  -0.59389326  0.07007589] [0.09573209]
# Iteration: 564 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 240
# this is car's states [-4.70087003 -0.59739706  0.07007589] [0.09573209]
# Iteration: 565 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 241
# this is car's states [-4.74151405 -0.60090085  0.07007589] [0.09573209]
# Iteration: 566 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 242
# this is car's states [-4.78233326 -0.60440465  0.07007589] [0.09573209]
# Iteration: 567 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 243
# this is car's states [-4.82332767 -0.60790844  0.07007589] [0.09573209]
# Iteration: 568 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 244
# this is car's states [-4.86449726 -0.61141224  0.07007589] [0.09573209]
# Iteration: 569 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 245
# this is car's states [-4.90584204 -0.61491603  0.07007589] [0.09573209]
# Iteration: 570 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 246
# this is car's states [-4.94736201 -0.61841983  0.07007589] [0.09573209]
# Iteration: 571 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 247
# this is car's states [-4.98905717 -0.62192362  0.07007589] [0.09573209]
# Iteration: 572 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 248
# this is car's states [-5.03092752 -0.62542742  0.07007589] [0.09573209]
# Iteration: 573 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 249
# this is car's states [-5.07297306 -0.62893121  0.07007589] [0.09573209]
# Iteration: 574 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 250
# this is car's states [-5.11519378 -0.63243501  0.07007589] [0.09573209]
# Iteration: 575 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 251
# this is car's states [-5.1575897  -0.6359388   0.07007589] [0.09573209]
# Iteration: 576 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 252
# this is car's states [-5.20016081 -0.63944259  0.07007589] [0.09573209]
# Iteration: 577 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 253
# this is car's states [-5.24290711 -0.64294639  0.07007589] [0.09573209]
# Iteration: 578 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 254
# this is car's states [-5.2858286  -0.64645018  0.07007589] [0.09573209]
# Iteration: 579 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 255
# this is car's states [-5.32892528 -0.64995398  0.07007589] [0.09573209]
# Iteration: 580 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 256
# this is car's states [-5.37219714 -0.65345777  0.07007589] [0.09573209]
# Iteration: 581 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 257
# this is car's states [-5.4156442  -0.65696157  0.07007589] [0.09573209]
# Iteration: 582 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 258
# this is car's states [-5.45926645 -0.66046536  0.07007589] [0.09573209]
# Iteration: 583 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 259
# this is car's states [-5.50306388 -0.66396916  0.07007589] [0.09573209]
# Iteration: 584 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 260
# this is car's states [-5.54703651 -0.66747295  0.07007589] [0.09573209]
# Iteration: 585 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 261
# this is car's states [-5.59118433 -0.67097675  0.07007589] [0.09573209]
# Iteration: 586 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 262
# this is car's states [-5.63550733 -0.67448054  0.07007589] [0.09573209]
# Iteration: 587 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 263
# this is car's states [-5.68000553 -0.67798434  0.07007589] [0.09573209]
# Iteration: 588 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 264
# this is car's states [-5.72467891 -0.68148813  0.07007589] [0.09573209]
# Iteration: 589 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 265
# this is car's states [-5.76952749 -0.68499192  0.07007589] [0.09573209]
# Iteration: 590 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 266
# this is car's states [-5.81455125 -0.68849572  0.07007589] [0.09573209]
# Iteration: 591 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 267
# this is car's states [-5.85975021 -0.69199951  0.07007589] [0.09573209]
# Iteration: 592 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 268
# this is car's states [-5.90512435 -0.69550331  0.07007589] [0.09573209]
# Iteration: 593 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 269
# this is car's states [-5.95067369 -0.6990071   0.07007589] [0.09573209]
# Iteration: 594 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 270
# this is car's states [-5.99639821 -0.7025109   0.07007589] [0.09573209]
# Iteration: 595 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 271
# this is car's states [-6.04229792 -0.70601469  0.07007589] [0.09573209]
# Iteration: 596 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 272
# this is car's states [-6.08837283 -0.70951849  0.07007589] [0.09573209]
# Iteration: 597 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 273
# this is car's states [-6.13462292 -0.71302228  0.07007589] [0.09573209]
# Iteration: 598 Cost: -1 Input: [0.09573209]
# Problem is infeasible.
# No solution 274
# this is car's states [-6.1810482  -0.71652608  0.07007589] [0.09573209]
# Iteration: 599 Cost: -1 Input: [0.09573209]
# aa

# %%
T_hw = 1.6
do = 1.5 #  distance gap between vehicles
dis = 0 - x_rev[:,0] - T_hw*x_rev[:,1] - 1.5
dis3 = x_rev[:,0]
dis2 = x_rev[:,0]/T_hw 
vh = dis2[1:] - dis2[:-1]

# print(dis[2:])
# velh = x_rev[:,1]
# dx = [0]
# d2x = [0]
# vel = [] 

# # for i in range(1,len(dis)):
# #    d2x.append(10 - dis[i] - T_hw*velh + do)
# #    velh = d2x[i] - d2x[i-1]
# #    vel.append(velh)


# dx = dis[2:] - dis[:-2]
# d2x = dis[2:] - 2*dis[1:-1] + dis[:-2]

plt.figure(figsize=(16, 16))   
fig, ax = plt.subplots()

ax.plot(dis, label='position_host', linewidth=2.5)
ax.plot(vh, label='velocity_host', linewidth=2.5)
ax.plot(dis2, label='check', linewidth=2.5)
# Create a cursor object and configure it to show the data values
# cursor = mplcursors.cursor(ax, hover=True)
# cursor.connect("add", lambda sel: sel.annotation.set_text(f'({sel.target[0]:.2f}, {sel.target[1]:.2f})'))

ax.legend()

# %%
def forward():
    print("start!! forward !!")
    A = np.array([[1,0.05,-0.00125], [0, 1 , -0.05],[0, 0, 1]])
    B = np.array([[-0], [-0.00125], [0.05]])
    #dt = 0.05
    (nx, nu) = B.shape
    
    # Q = np.array([[100 , 10, 10],[10,10,10],[10,10,10]])
    Q = np.array([[0.05 , 0, 0],[0,0.0075,0],[0,0,0.0075]])
    R = np.eye(nu)*0.5
    P = np.eye(nx)*0.1

    x0 = np.array([100.0, 16.0, 0]) # initial state
    umax = 0.4
    umin = -0.8

    xmin = np.array([[3], [-50], [-4.5]])  # state constraints
    xmax = np.array([[600], [50.0],[3.0]])  # state constraints

    x_current = x0
    N = 15  # number of horizon
    iter = 60
    x_hist = [x_current]
    u_hist = []
    cost_hist = []
    # run = min( (x_rev.size/3-15), iter - N )  
    # for i in range(int(x_rev.size/3) - N -1): #iter -N-2  
    #     xr = x_rev[i:i+N,:]
    #     is_sol, x, u, c = cvxpy_forward(A, B, N,R, x0, xr, umax=umax, umin=umin, xmin=xmin, xmax=xmax)
    #     # print('Iteration:', i) #, 'Cost:', c, 'Input:', u[:,0])
    #     if  is_sol :
    #         x0 = A.dot(x[:,0]) + B.dot(u[:,0])
    #         u_hist.append(u[:,0])
    #         x_hist.append(x0)
    #         cost_hist.append(c)
    #     else:
    #          print('No solution',i)
    #          break
    
    for i in range(iter):
        notfail, x, u, c = cvxpy_reverse(A, B, N, Q, R, P, x0, xr, umax, umin, xmin, xmax)
        # print('Iteration:', i) #, 'Cost:', c, 'Input:', u[:,0])
        if  notfail :
            x0 = A.dot(x[:,0]) + B.dot(u[:,0]) #+ np.random.multivariate_normal(np.zeros(3), W)
            u_hist.append(u[:,0])
            x_hist.append(x0)
            cost_hist.append(c)
        else:
             print('No solution',i)
             break

    print("aa")
    Xh = []
    # Xr = [int(xr[0,0])]
    xr = np.array([8.0, 0 , 0])
    diff = []
    Vr = 0
    x_hist = np.array(x_hist)
    for k in range(1,len(x_hist[:,0])):
        # Xr.append( Vr*0.5) #Xr[k-1] +
        Xh.append( x_hist[k,0]) #Xr[k] - 
        diff.append(-x_hist[k,0])

    plotting(x_hist,u_hist,cost_hist,Xh,xr,diff,True)

# %%
def cvxpy_forward(A, B, N, R, x0, xr, umax=None, umin=None, xmin=None, xmax=None):
    f =  False
    (nx, nu) = B.shape

    # mpc calculation x0 = distance, x1 = velocity, x2 = accel  
    x = cvxpy.Variable((nx, N + 1))
    u = cvxpy.Variable((nu, N))
    w1 = 1
    w2 = 0.5
    w3 = 0.2

    costlist = 0.0
    constraints = []
    # print("this is size of xr" , xr.size)
    
    for t in range(N):
        costlist +=  (w3*((x[0, t])) + w2*(x[2, t]) +  w1*((x[1, t])) ) # -xr[t,2]
        costlist += 0.5*u[:, t] #0.05 * cvxpy.quad_form(u[:, t], R)

        constraints += [x[:, t + 1] == A * x[:, t] + B * u[:, t]]

        if xmin is not None:
            constraints += [x[:, t] >= xmin[:, 0]]
        if xmax is not None:
            constraints += [x[:, t] <= xmax[:, 0]]

    costlist +=  0.5 *((x[1, N]) + (x[2, N]) + (x[0, N])) #0.5* (((x[2, N]-xr[N,2])**2  + ((x[1, N]-xr[N,1]))**2))  # terminal cost ((x[0, t]- xr[t,0])/100)**2
    if xmin is not None:
        constraints += [x[:, N] >= xmin[:, 0]]
    if xmax is not None:
        constraints += [x[:, N] <= xmax[:, 0]]

    if umax is not None:
        constraints += [u <= umax]  # input constraints
    if umin is not None:
        constraints += [u >= umin]  # input constraints

    constraints += [x[:, 0] == x0]  # inital state constraints

    prob = cvxpy.Problem(cvxpy.Minimize(costlist), constraints)

    prob.solve(solver=ECOS , warm_start=True) #solver= OSQP,
    if prob.status == 'optimal':
        f = True
    
    return f , x.value, u.value, costlist.value
